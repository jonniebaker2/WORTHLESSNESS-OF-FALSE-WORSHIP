# %% [markdown]
# Queries for WORTHLESSNESS OF FALSE WORSHIP (OTST 686)

# %%
from tf.fabric import Fabric
from tf.app import use

# %%
BHS = use('etcbc/bhsa', version="2021", mod='CenterBLC/BHSaddons/tf')
#BHSa2017 = use('etcbc/bhsa', version='2017')
#BHSaLatest = use('etcbc/bhsa:latest')
#BHSaC = use('etcbc/bhsa', version='c', mod='CenterBLC/BHSaddons/tf')
LXX = use("CenterBLC/LXX", version="1935")
DSS = use('etcbc/dss')
GNT = use ("CenterBLC/N1904", version="1.0.0", mod="CenterBLC/N1904/BOLcomplement/tf/", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv1.8.1=#gb112c161cfd21eae403d51a2733740d8743460e7 offline under /Users/jonathanbaker/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/app</span>
# <b title="local release">data:</b> <span title="rv1.8.1=#gb112c161cfd21eae403d51a2733740d8743460e7 offline under /Users/jonathanbaker/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/tf/2021</span>
# <b title="local release">data:</b> <span title="rv1.0.4=#b85ab6e676c425ed8ca20c649daf9099bce26627 offline under /Users/jonathanbaker/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#gaba4367b49750089e4e4122415a77cac43bd97bc offline under /Users/jonathanbaker/text-fabric-data/github">~/text-fabric-data/github/etcbc/phono/tf/2021</span>
# ...

# %% [raw]
# 1. HBL in the Book of Jeremia

# %%
BHSJeremiahSearch = '''
book book=Jeremia
    word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=8, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.25s 8 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Jeremia&amp;chapter=2&amp;verse=5&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Jeremiah 2:5">Jeremiah 2:5</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">הֶ֖בֶל </span></span></span></td></tr>
# ...

# %% [raw]
# 2. HBL in the Old Testament

# %%
BHSJeremiahSearch = '''
verse
    word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.25s 73 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=32&amp;verse=21&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Deuteronomy 32:21">Deuteronomy 32:21</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">הַבְלֵיהֶ֑ם </span></span></span></td></tr>
# ...

# %% [raw]
# 3. HBL Plus the Verbal Form

# %%
BHSJeremiahSearch = '''
verse
    word lex=HBL/
    word lex=HBL[
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=100, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.52s 3 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_II&amp;chapter=17&amp;verse=15&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="2_Kings 17:15">2_Kings 17:15</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">הֶ֨בֶל֙ </span></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">יֶּהְבָּ֔לוּ </span></span></span></td></tr>
# ...

# %% [raw]
# 4. Phrase Functions of HBL

# %%
BHSJeremiahSearch = '''
clause
    phrase function=Cmpl
        word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.50s 8 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word <span title="clause, phrase">(+2)</span></th><th class="tf">phrase <span title="clause, word">(+2)</span></th><th class="tf">clause <span title="word, phrase">(+2)</span></th></tr>
# ...

# %%
BHSJeremiahSearch = '''
clause
     phrase function=PreC
         word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.40s 39 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">phrase <span title="clause, word">(+2)</span></th><th class="tf">word <span title="clause, phrase">(+2)</span></th><th class="tf">clause <span title="phrase, word">(+2)</span></th><th class="tf">clause</th><th class="tf">word</th><th class="tf">phrase</th></tr>
# ...

# %%
BHSJeremiahSearch = '''
clause
     phrase function=Objc
         word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.46s 7 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">clause <span title="phrase, word">(+2)</span></th><th class="tf">word <span title="clause, phrase">(+2)</span></th><th class="tf">phrase <span title="word">(+1)</span></th></tr>
# ...

# %%
BHSJeremiahSearch = '''
clause
     phrase function=Subj
         word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.48s 4 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word <span title="phrase">(+1)</span></th><th class="tf">clause <span title="word">(+1)</span></th><th class="tf">phrase <span title="word">(+1)</span></th><th class="tf">clause</th></tr>
# ...

# %%
BHSJeremiahSearch = '''
clause
     phrase function=Time
         word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.39s 4 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word <span title="phrase">(+1)</span></th><th class="tf">phrase <span title="word">(+1)</span></th><th class="tf">clause</th><th class="tf">word</th></tr>
# ...

# %%
BHSJeremiahSearch = '''
clause
     phrase function=Modi
         word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.43s 5 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">phrase <span title="clause">(+1)</span></th><th class="tf">word <span title="clause, phrase">(+2)</span></th><th class="tf">clause <span title="word, phrase">(+2)</span></th></tr>
# ...

# %%
BHSJeremiahSearch = '''
clause
     phrase function=Frnt
         word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.39s 1 result
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th><th class="tf">clause</th><th class="tf">phrase</th></tr>
# ...

# %%
BHSJeremiahSearch = '''
clause
     phrase function=Adju
         word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.45s 5 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word <span title="clause, phrase">(+2)</span></th><th class="tf">clause <span title="phrase, word">(+2)</span></th><th class="tf">clause <span title="phrase, word">(+2)</span></th></tr>
# ...

# %% [raw]
# 5. Phrase Function of HBL in Jeremia

# %%
BHSJeremiahSearch = '''
book book=Jeremia
    clause
         phrase function=Cmpl
             word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.28s 2 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th><th class="tf">clause</th><th class="tf">phrase</th></tr>
# ...

# %%
BHSJeremiahSearch = '''
book book=Jeremia
    clause
         phrase function=PreC
             word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.30s 3 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">phrase <span title="clause">(+1)</span></th><th class="tf">word</th><th class="tf">clause <span title="phrase">(+1)</span></th></tr>
# ...

# %% [raw]
# 6. HBL with the Article

# %%
BHSJeremiahSearch = '''
clause
    w1:word lex=H
    w2:word lex=HBL/
    w1 <: w2
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.51s 5 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word <span title="clause">(+1)</span></th><th class="tf">word <span title="clause">(+1)</span></th><th class="tf">word <span title="clause">(+1)</span></th></tr>
# ...

# %% [raw]
# 7. B<L with the Article

# %%
BHSJeremiahSearch = '''
clause
    w1:word lex=H
    w2:word lex=B<L/
    w1 <: w2
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.51s 76 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word <span title="clause">(+1)</span></th><th class="tf">word <span title="clause">(+1)</span></th><th class="tf">word <span title="clause">(+1)</span></th></tr>
# ...

# %% [raw]
# 8. HBL Verbal Form

# %%
BHSJeremiahSearch = '''
word lex=HBL[ vs=qal
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=100, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.23s 4 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_II&amp;chapter=17&amp;verse=15&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="2_Kings 17:15">2_Kings 17:15</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">יֶּהְבָּ֔לוּ </span></span></span></td></tr>
# ...

# %%
BHSJeremiahSearch = '''
word lex=HBL[
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=100, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.23s 5 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_II&amp;chapter=17&amp;verse=15&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="2_Kings 17:15">2_Kings 17:15</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">יֶּהְבָּ֔לוּ </span></span></span></td></tr>
# ...

# %% [raw]
# 9. PSL in the Old Testament

# %%
BHSJeremiahSearch = '''
word lex=PSJL/|PSL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.25s 54 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=20&amp;verse=4&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Exodus 20:4">Exodus 20:4</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">פֶ֣֨סֶל֙׀ </span></span></span></td></tr>
# ...

# %%
BHSJeremiahSearch = '''
word lex=PSL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=8, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.14s 31 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=20&amp;verse=4&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Exodus 20:4">Exodus 20:4</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">פֶ֣֨סֶל֙׀ </span></span></span></td></tr>
# ...

# %% [raw]
# 10. PSL and HBL in the same clause

# %%
BHSJeremiahSearch = '''
clause
    word lex=PSJL/|PSL/
    word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=8, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.48s 1 result
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th><th class="tf">clause</th><th class="tf">word</th></tr>
# ...

# %% [raw]
# 11. Phrase Function of PSL

# %%
BHSJeremiahSearch = '''
clause
     phrase function=Cmpl
         word lex=PSJL/|PSL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=8, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.41s 10 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">clause <span title="word">(+1)</span></th><th class="tf">word <span title="phrase">(+1)</span></th><th class="tf">phrase <span title="word, clause">(+2)</span></th></tr>
# ...

# %% [raw]
# 12. PSL and HBL in Deuteronomium

# %%
BHSJeremiahSearch = '''
book book=Deuteronomium
    word lex=PSL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=8, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.30s 5 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=4&amp;verse=16&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Deuteronomy 4:16">Deuteronomy 4:16</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">פֶּ֖סֶל </span></span></span></td></tr>
# ...

# %%
BHSJeremiahSearch = '''
book book=Deuteronomium
    word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=8, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.25s 1 result
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=32&amp;verse=21&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Deuteronomy 32:21">Deuteronomy 32:21</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">הַבְלֵיהֶ֑ם </span></span></span></td></tr></table>

# %% [raw]
# 13. PSL in Jeremia

# %%
BHSJeremiahSearch = '''
book book=Jeremia
    word lex=PSJL/|PSL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=8, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.35s 6 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Jeremia&amp;chapter=8&amp;verse=19&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Jeremiah 8:19">Jeremiah 8:19</a></span></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"></span></td><td class="tf rtl"><span class="rtl ubd pl-mode"><span class="plain rtl  hl" ><span class="txtu hbo">פְסִלֵיהֶ֖ם </span></span></span></td></tr>
# ...

# %% [raw]
# 14. HBL in Ecclesiastes

# %%
BHSJeremiahSearch = '''
verse book=Ecclesiastes
    word lex=HBL/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   0.26s 38 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th><th class="tf">word</th></tr>
# ...

# %% [raw]
# 15. "Go after other gods"

# %%
BHSJeremiahSearch = '''
clause
    phrase function=Pred
        word lex=HLK[
    phrase typ=PP
        word lex=>XR/
    phrase function=Cmpl
        word lex=>LHJM/
        word lex=>XR=/
'''
BHSJeremiahSearch  = BHS.search(BHSJeremiahSearch)
BHS.table(BHSJeremiahSearch, start=1, end=10, extraFeatures={'function', 'lex_utf8'}, condensed=True)
# Out:
#   1.41s 17 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">verse</th><th class="tf">word <span title="phrase, clause">(+2)</span></th><th class="tf">word <span title="phrase">(+1)</span></th><th class="tf">word <span title="clause, phrase">(+2)</span></th><th class="tf">word <span title="clause, phrase">(+2)</span></th><th class="tf">word <span title="clause">(+1)</span></th><th class="tf">word <span title="phrase, clause">(+2)</span></th><th class="tf">phrase <span title="word, clause">(+2)</span></th><th class="tf">phrase</th></tr>
# ...
